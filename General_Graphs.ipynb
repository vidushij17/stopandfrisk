# %%
import pandas as pd

file_path = "sqf-2023-cleaned-with-features-FINAL.csv"

df_cleaned = pd.read_csv(file_path)

# %%
#General graphs:
df_cleaned['SUSPECT_REPORTED_AGE'].plot(kind='hist', bins=30, color='skyblue', edgecolor='black', title="Distribution of Suspect Ages")
# Out:
# <Axes: title={'center': 'Distribution of Suspect Ages'}, ylabel='Frequency'>

# %%
sex_counts = {
    'Female': df_cleaned['SUSPECT_SEX_FEMALE'].sum(),
    'Male': df_cleaned['SUSPECT_SEX_MALE'].sum()
}

# Creating a bar chart
import matplotlib.pyplot as plt

plt.bar(sex_counts.keys(), sex_counts.values(), color=['pink', 'blue'])
plt.title("Suspect Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
# Summing the counts for each race
race_counts = {
    'American Indian/Alaskan Native': df_cleaned['SUSPECT_RACE_DESCRIPTION_AMERICAN INDIAN/ALASKAN NATIVE'].sum(),
    'Asian / Pacific Islander': df_cleaned['SUSPECT_RACE_DESCRIPTION_ASIAN / PACIFIC ISLANDER'].sum(),
    'Black': df_cleaned['SUSPECT_RACE_DESCRIPTION_BLACK'].sum(),
    'Black Hispanic': df_cleaned['SUSPECT_RACE_DESCRIPTION_BLACK HISPANIC'].sum(),
    'Middle Eastern/Southwest Asian': df_cleaned['SUSPECT_RACE_DESCRIPTION_MIDDLE EASTERN/SOUTHWEST ASIAN'].sum(),
    'White': df_cleaned['SUSPECT_RACE_DESCRIPTION_WHITE'].sum(),
    'White Hispanic': df_cleaned['SUSPECT_RACE_DESCRIPTION_WHITE HISPANIC'].sum()
}

# Creating a bar chart
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Optional: Adjust figure size for better readability
plt.bar(race_counts.keys(), race_counts.values(), color=['red', 'orange', 'black', 'brown', 'purple', 'gray', 'cyan'])
plt.title("Suspect Race Distribution")
plt.xlabel("Race")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()  # Adjust layout for readability
plt.show()

# %%
# Using the race_counts dictionary from the previous step
import matplotlib.pyplot as plt

# Creating a pie chart
plt.figure(figsize=(8, 8))  # Adjust the figure size as needed
plt.pie(
    race_counts.values(), 
    labels=race_counts.keys(), 
    autopct='%1.1f%%',  # Display percentage with one decimal
    startangle=140,  # Rotate the pie chart for better alignment
    colors=['red', 'orange', 'green', 'brown', 'purple', 'gray', 'cyan']
)
plt.title("Suspect Race Distribution")
plt.axis('equal')  # Ensures the pie chart is a circle
plt.show()

# %%
time_of_day_counts = {
    "Morning": df_cleaned["TIME_OF_DAY_Morning"].sum(),
    "Afternoon": df_cleaned["TIME_OF_DAY_Afternoon"].sum(),
    "Evening": df_cleaned["TIME_OF_DAY_Evening"].sum(),
    "Night": df_cleaned["TIME_OF_DAY_Night"].sum()
}
import matplotlib.pyplot as plt

# Plotting a bar chart
plt.figure(figsize=(8, 6))
plt.bar(time_of_day_counts.keys(), time_of_day_counts.values(), color=["blue", "orange", "green", "purple"])
plt.title("Distribution of Stops by Time of Day")
plt.xlabel("Time of Day")
plt.ylabel("Number of Stops")
plt.show()

# %%
df_cleaned.plot(kind='scatter', x='STOP_LOCATION_X', y='STOP_LOCATION_Y', alpha=0.5, title="Stop Locations")
# Out:
# <Axes: title={'center': 'Stop Locations'}, xlabel='STOP_LOCATION_X', ylabel='STOP_LOCATION_Y'>

# %%
# Aggregate counts for boroughs
borough_counts = {
    "Bronx": df_cleaned["STOP_LOCATION_BORO_NAME_BRONX"].sum(),
    "Brooklyn": df_cleaned["STOP_LOCATION_BORO_NAME_BROOKLYN"].sum(),
    "Manhattan": df_cleaned["STOP_LOCATION_BORO_NAME_MANHATTAN"].sum(),
    "Queens": df_cleaned["STOP_LOCATION_BORO_NAME_QUEENS"].sum(),
    "Staten Island": df_cleaned["STOP_LOCATION_BORO_NAME_STATEN ISLAND"].sum()
}
import matplotlib.pyplot as plt

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(borough_counts.keys(), borough_counts.values(), color=["blue", "orange", "green", "red", "purple"])
plt.title("Distribution of Stops by Borough")
plt.xlabel("Borough")
plt.ylabel("Number of Stops")
plt.xticks(rotation=45)  # Rotate borough names for better readability if needed
plt.show()
